# %%
lst1=[]
def lst_square(lst):
    for i in lst:
        lst1.append(i*i)
    return lst1

# %%
lst_square([1,2,3,4,5,6,7])
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
lst = [1, 2, 3, 4, 5, 6, 7]

# %%
lst2= [i*i for i in lst]

# %%
print(lst2)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
#only for even numbers

# %%
lst3 = [i*i for i in lst if i%2==0]

# %%
print(lst3)
# Out:
# [4, 16, 36]
