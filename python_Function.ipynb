# %% [markdown]
# # Functions

# %%
num = 24

# %%
def even_odd(num):
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")

# %%
even_odd(num)
# Out:
# The number is even

# %%
# print vs return
def hello_world():
    print("Hello welcome!")

# %%
hello_world
# Out:
# <function __main__.hello_world()>

# %%
hello_world()
# Out:
# Hello welcome!

# %%
val = hello_world()
# Out:
# Hello welcome!

# %%
# ab jum hum val call krege, it will return None
print(val)
# Out:
# None

# %%
def hello():
    return "Hello Dishaaa!"

# %%
val = hello()

# %%
print(val)
# Out:
# Hello Dishaaa!

# %%
def add_numbers(num1, num2):
    return num1+num2

# %%
sums = add_numbers(45, 68)

# %%
sums
# Out:
# 113

# %%
# parameter is function bnate samay jo variables
# arguments is function call ke samay values
def identity(name, age=29):
    print("My name is {} and age is {}".format(name, age))

# %%
identity("Disha")
# Out:
# My name is Disha and age is 29

# %%
def hello(*args, **kwargs):
    print(args)
    print(kwargs)

# %%
hello("Disha", "Verma", age = 21, height = "5'4")
# Out:
# ('Disha', 'Verma')
# {'age': 21, 'height': "5'4"}

# %%
list = ['Disha', 'Verma']
dict = {'age': 21, 'height': "5'4"}

# %%
hello(list, dict)
# by default isne isko 1 he argument consider kr liya hai, sooooo.....
# Out:
# (['Disha', 'Verma'], {'age': 21, 'height': "5'4"})
# {}

# %%
hello(*list, **dict)
# Out:
# ('Disha', 'Verma')
# {'age': 21, 'height': "5'4"}

# %%
lst = [1, 2, 3, 4, 5, 6, 7, 8]

# %%
def evenodd(lst):
    even_sum = 0
    odd_sum = 0
    for i in lst:
        if i % 2 == 0:
            even_
