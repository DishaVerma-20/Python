# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# # Correaltion with Heatmap

# %%
df. corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df. corr()
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:13133, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13129         """  # noqa: E501
#   13130         data = self._get_numeric_data() if numeric_only else self
#   13131         cols = data.columns
#   13132         idx = cols.copy()
# > 13133         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13134
#   13135         if method == "pearson":
#   13136             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    2078         """
#    2079         if dtype is not None:
# ...

# %%
corr = df.corr(numeric_only = True)

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
tips = sns.load_dataset('tips')
sns.displot(tips, x = 'total_bill', kde = True)

# %%
sns.histplot(tips['total_bill'], kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.jointplot(
    data = tips,
    x = 'total_bill',
    y = 'tip'
)

# %%
sns.pairplot(tips)

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.boxplot(tips['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(tips['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.violinplot(x = tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.countplot(x = 'sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.jointplot(x = 'tip', y = 'total_bill', kind = 'hex', data = df)

# %%
sns.jointplot(x = 'tip', y = 'total_bill', kind = 'reg', data = df)

# %%
sns.pairplot(df, hue = 'sex')

# %%
sns.boxplot(x='day', y='total_bill', data = df, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.boxplot(x='day', y='total_bill', data = df, hue='sex', palette = 'rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data = df, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
