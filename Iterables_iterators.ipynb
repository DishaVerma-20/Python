# %%
lst = [1, 2, 3, 4, 5, 6, 7]

# %%
for i in lst:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
lst1 = iter(lst)

# %%
lst1

# %%
next(lst1)
# Out:
# 1

# %%
for i in lst1:
    print(i)
# pointer aagey 2 pr chla gaya
# not initialized at once
# initialized one by one
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
# iterator elements are generated/accessed only when needed
# next() or a loop requests the next value
# exception is already handled in for loop
# but if we uses next(), then it will show error

# %%
# !git add iterables_itera
